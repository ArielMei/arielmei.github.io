# %% [markdown]
# **Please install plotly first.**
# ```Python
# pip install plotly
# ```

# %%
from plotly.graph_objs import Scatter,Layout
import plotly
import plotly.offline as py
import numpy as np
import plotly.graph_objs as go

# %%
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # Line Chart

# %%
N = 100
random_x = np.linspace(0,1,N)
random_y0 = np.random.randn(N)+5
random_y1 = np.random.randn(N)
random_y2 = np.random.randn(N)-5

trace0 = go.Scatter( x = random_x, y = random_y0, mode = 'markers', name = 'markers')
trace1 = go.Scatter( x = random_x, y = random_y1, mode = 'lines+markers', name = 'lines+markers')
trace2 = go.Scatter( x = random_x, y = random_y2, mode = 'lines', name = 'lines')

data = [trace0,trace1,trace2]
py.iplot(data)
# Out:
# <div id="43d6282d-f5d1-40f2-996c-08f2a2b8f741" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("43d6282d-f5d1-40f2-996c-08f2a2b8f741")) {
#     Plotly.newPlot("43d6282d-f5d1-40f2-996c-08f2a2b8f741", [{"mode": "markers", "name": "markers", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [2.5387871031901894, 6.395388524866716, 5.534655515283862, 5.713917836595744, 4.707419374710093, 5.311397595384762, 5.685724616100541, 4.54398515576454, 5.319144864581586, 2.7381124364501717, 6.043935804946823, 3.574015841338007, 2.9751452487103234, 4.638441740307682, 6.903342677964119, 5.456429202788655, 6.164524990209865, 3.7727683538272863, 4.134649489516335, 3.6846050260390353, 4.327016804590731, 4.334847527825557, 3.1968468602759987, 4.294261546463627, 4.547398655413504, 5.066536218970527, 4.625292128294901, 3.9135687858524766, 5.125975935705797, 4.939105170497363, 5.9318343272608685, 6.272316799059756, 5.740792155909761, 5.64694469573984, 4.614661506629731, 4.200981115472692, 5.179398491861025, 5.6421379724957745, 4.071448169376427, 5.348111486832217, 5.017614197048892, 4.879243032463299, 5.873180779906154, 5.467364623981762, 5.056141579079552, 5.7768360840542226, 4.776873485092899, 5.191151343304517, 6.6484875553787255, 4.65117043172582, 4.053547453484579, 4.933191283758207, 5.60712826478857, 4.249193900282123, 3.2300419972752614, 4.329647703376643, 7.6590844215294815, 5.7123345606927405, 5.28396195599023, 4.724360521056201, 3.410764437915601, 4.187421844413294, 5.275386984604878, 4.541459404113619, 4.747069033111011, 3.360418039449068, 4.853896629088428, 5.211065702956252, 5.022077729516599, 6.795221249704139, 6.0766407058973275, 5.022876644666577, 4.221556956459921, 6.645644932243274, 6.998241670956195, 6.525666846195497, 5.319201099275682, 5.304862252187961, 4.988275768039602, 6.0444877443892775, 5.305123141742696, 5.806281016910795, 3.686057775205429, 3.860090197698305, 5.618074359873893, 3.875246052961996, 4.924935939150897, 5.025872179606711, 5.00762198234055, 4.958052926282966, 6.132502711934373, 6.5553525612979175, 5.7774534274395215, 4.682868831334276, 5.665374554052372, 4.5425395838586775, 4.8328512802187324, 6.559552815166436, 4.448951323 ...

# %% [markdown]
# # Scatter Chart

# %%
trace1 = go.Scatter(y = np.random.randn(500), mode = 'markers', 
                   marker = dict(size = 16, color = np.random.randn(500), colorscale = 'Viridis', showscale = True))
data = [trace1]
py.iplot(data,filename='scatter_plot_with_colorscale')
# Out:
# <div id="8b892155-f054-4aaa-91a1-4773ed2f6867" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById
, -1.6790616165339225, -1.5891604748313786, -0.601466604874948, 1.271399791338229, -2.2002008296950937, -1.8261563312550781, -0.1844380978253421, 0.3856978308548219, 0.33570805881746396, 0.6174427593288206, 1.1771996549681776, -0.030976261422035422, -2.005857901293088, 0.039394087679860884, -0.7287417270914879, -0.12155137326828527, -0.7230782596920594, -0.4375932743049691, 0.6758914607040519, -0.2897486787485857, -0.3104497828433662, -0.7768557684585795, 0.16478377341055686, 2.166028890590382, -1.2518734488626417, -0.046982700242430196, 0.22478221447125615, 1.5556160486556347, -0.41034983423808913, -1.12430152907727, -0.5112645428850697, 0.16378659475851692, 2.5533570556896725, -0.6175129953671361, 0.9595096771498833, -1.2410598942505628, -0.955329679559 ...

# %% [markdown]
# # Buble Chart

# %%
data = [{'x':[1, 3.2, 5.4, 7.6, 9.8, 12.5],
         'y':[1, 3.2, 5.4, 7.6, 9.8, 12.5],
         'mode':'markers',
         'marker':{'color': [120,125,130,135,140,145],
                   'size': [15,30,55,70,90,110],
                   'showscale': True}
        }]
py.iplot(data)
# Out:
# <div id="bbcc2502-beed-4b40-83c4-0a0b82087f60" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("bbcc2502-beed-4b40-83c4-0a0b82087f60")) {
#     Plotly.newPlot("bbcc2502-beed-4b40-83c4-0a0b82087f60", [{"marker": {"color": [120, 125, 130, 135, 140, 145], "showscale": true, "size": [15, 30, 55, 70, 90, 110]}, "mode": "markers", "x": [1, 3.2, 5.4, 7.6, 9.8, 12.5], "y": [1, 3.2, 5.4, 7.6, 9.8, 12.5], "type": "scatter", "uid": "aea94e84-2f96-413c-a33b-c946bfb06b3c"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("bbcc2502-beed-4b40-83c4-0a0b82087f60")) {window._Plotly.Plots.resize(document.getElementById("bbcc2502-beed-4b40-83c4-0a0b82087f60"));};})</script>

# %% [markdown]
# # Bar Chart

# %%
trace0 = go.Bar(x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                y = [20, 14, 25, 16, 18, 22, 19, 15, 12, 16, 14, 17],
                name = 'Primary Product',
                marker = dict(color = 'rgb(49,130,189)')
               )
trace1 = go.Bar(x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                y = [19, 14, 22, 14, 16, 19, 15, 14, 10, 12, 12, 16],
                name = 'Secondary Product',
                marker = dict(color = 'rgb(204,204,204)')
               )
data = [trace0,trace1]
py.iplot(data)
# Out:
# <div id="026fbd63-7a9a-4a07-9899-837b2d10dc8b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("026fbd63-7a9a-4a07-9899-837b2d10dc8b")) {
#     Plotly.newPlot("026fbd63-7a9a-4a07-9899-837b2d10dc8b", [{"marker": {"color": "rgb(49,130,189)"}, "name": "Primary Product", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [20, 14, 25, 16, 18, 22, 19, 15, 12, 16, 14, 17], "type": "bar", "uid": "f7d1f2f9-09c9-4016-a4a8-0da5837d21f2"}, {"marker": {"color": "rgb(204,204,204)"}, "name": "Secondary Product", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [19, 14, 22, 14, 16, 19, 15, 14, 10, 12, 12, 16], "type": "bar", "uid": "7af8d68e-545a-40e9-8588-1d595298442c"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("026fbd63-7a9a-4a07-9899-837b2d10dc8b")) {window._Plotly.Plots.resize(document.getElementById("026fbd63-7a9a-4a07-9899-837b2d10dc8b"));};})</script>
